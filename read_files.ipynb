# %% [markdown]
# **Read a CSV file using standard way.**

# %%
orders_df = spark.read \
.format("csv") \
.option("header", "true") \
.option("inferschema", "true") \
.load("/Volumes/workspace/spark_practice/datasets/orders_1gb.csv")

# %%
orders_df.show()
# Out:
# +---+---------------------+-----+---------------+
# |  1|2013-07-25 00:00:00.0|11599|         CLOSED|
# +---+---------------------+-----+---------------+
# |  2|  2013-07-25 00:00:00|  256|PENDING_PAYMENT|
# |  3|  2013-07-25 00:00:00|12111|       COMPLETE|
# |  4|  2013-07-25 00:00:00| 8827|         CLOSED|
# |  5|  2013-07-25 00:00:00|11318|       COMPLETE|
# |  6|  2013-07-25 00:00:00| 7130|       COMPLETE|
# |  7|  2013-07-25 00:00:00| 4530|       COMPLETE|
# |  8|  2013-07-25 00:00:00| 2911|     PROCESSING|
# |  9|  2013-07-25 00:00:00| 5657|PENDING_PAYMENT|
# | 10|  2013-07-25 00:00:00| 5648|PENDING_PAYMENT|
# | 11|  2013-07-25 00:00:00|  918| PAYMENT_REVIEW|
# | 12|  2013-07-25 00:00:00| 1837|         CLOSED|
# | 13|  2013-07-25 00:00:00| 9149|PENDING_PAYMENT|
# | 14|  2013-07-25 00:00:00| 9842|     PROCESSING|
# | 15|  2013-07-25 00:00:00| 2568|       COMPLETE|
# | 16|  2013-07-25 00:00:00| 7276|PENDING_PAYMENT|
# | 17|  2013-07-25 00:00:00| 2667|       COMPLETE|
# | 18|  2013-07-25 00:00:00| 1205|         CLOSED|
# | 19|  2013-07-25 00:00:00| 9488|PENDING_PAYMENT|
# | 20|  2013-07-25 00:00:00| 9198|     PROCESSING|
# | 21|  2013-07-25 00:00:00| 2711|        PENDING|
# +---+---------------------+-----+---------------+
# only showing top 20 rows

# %%
orders_df.printSchema()
# Out:
# root
#  |-- 1: integer (nullable = true)
#  |-- 2013-07-25 00:00:00.0: timestamp (nullable = true)
#  |-- 11599: integer (nullable = true)
#  |-- CLOSED: string (nullable = true)

# %% [markdown]
# **Read CSV file using shortcut method**

# %%
spark.read.csv("/Volumes/workspace/spark_practice/datasets/orders_1gb.csv", header = "true", inferSchema = "true").show()
# Out:
# +---+---------------------+-----+---------------+
# |  1|2013-07-25 00:00:00.0|11599|         CLOSED|
# +---+---------------------+-----+---------------+
# |  2|  2013-07-25 00:00:00|  256|PENDING_PAYMENT|
# |  3|  2013-07-25 00:00:00|12111|       COMPLETE|
# |  4|  2013-07-25 00:00:00| 8827|         CLOSED|
# |  5|  2013-07-25 00:00:00|11318|       COMPLETE|
# |  6|  2013-07-25 00:00:00| 7130|       COMPLETE|
# |  7|  2013-07-25 00:00:00| 4530|       COMPLETE|
# |  8|  2013-07-25 00:00:00| 2911|     PROCESSING|
# |  9|  2013-07-25 00:00:00| 5657|PENDING_PAYMENT|
# | 10|  2013-07-25 00:00:00| 5648|PENDING_PAYMENT|
# | 11|  2013-07-25 00:00:00|  918| PAYMENT_REVIEW|
# | 12|  2013-07-25 00:00:00| 1837|         CLOSED|
# | 13|  2013-07-25 00:00:00| 9149|PENDING_PAYMENT|
# | 14|  2013-07-25 00:00:00| 9842|     PROCESSING|
# | 15|  2013-07-25 00:00:00| 2568|       COMPLETE|
# | 16|  2013-07-25 00:00:00| 7276|PENDING_PAYMENT|
# | 17|  2013-07-25 00:00:00| 2667|       COMPLETE|
# | 18|  2013-07-25 00:00:00| 1205|         CLOSED|
# | 19|  2013-07-25 00:00:00| 9488|PENDING_PAYMENT|
# | 20|  2013-07-25 00:00:00| 9198|     PROCESSING|
# | 21|  2013-07-25 00:00:00| 2711|        PENDING|
# +---+---------------------+-----+---------------+
# only showing top 20 rows

# %%
df_parquet = spark.read.parquet("/Volumes/workspace/spark_practice/datasets/part-00000-07b99d8a-8ee4-41c6-85d8-70e9799b157a-c000.snappy.parquet", header = "true", inferSchema = "true")
df_parquet.show()
# Out:
# +--------+----------+-------+---------------+
# |order_id|order_date|cust_id|   order_status|
# +--------+----------+-------+---------------+
# |       1|2013-07-25|  11599|         CLOSED|
# |       2|2013-07-25|    256|PENDING_PAYMENT|
# |       3|2013-07-25|  12111|       COMPLETE|
# |       4|2013-07-25|   8827|         CLOSED|
# |       5|2013-07-25|  11318|       COMPLETE|
# |       6|2013-07-25|   7130|       COMPLETE|
# |       7|2013-07-25|   4530|       COMPLETE|
# |       8|2013-07-25|   2911|     PROCESSING|
# |       9|2013-07-25|   5657|PENDING_PAYMENT|
# |      10|2013-07-25|   5648|PENDING_PAYMENT|
# |      11|2013-07-25|    918| PAYMENT_REVIEW|
# |      12|2013-07-25|   1837|         CLOSED|
# |      13|2013-07-25|   9149|PENDING_PAYMENT|
# |      14|2013-07-25|   9842|     PROCESSING|
# |      15|2013-07-25|   2568|       COMPLETE|
# |      16|2013-07-25|   7276|PENDING_PAYMENT|
# |      17|2013-07-25|   2667|       COMPLETE|
# |      18|2013-07-25|   1205|         CLOSED|
# |      19|2013-07-25|   9488|PENDING_PAYMENT|
# |      20|2013-07-25|   9198|     PROCESSING|
# +--------+----------+-------+---------------+
# only showing top 20 rows

# %%
df_parquet.printSchema()
# Out:
# root
#  |-- order_id: long (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- cust_id: long (nullable = true)
#  |-- order_status: string (nullable = true)

# %%
df_json = spark.read.json("/Volumes/workspace/spark_practice/datasets/part-00000-68544d18-9a34-443f-bf0e-1dd8103ff94e-c000.json")
df_json.show()
# Out:
# +-----------+--------------------+--------+---------------+
# |customer_id|          order_date|order_id|   order_status|
# +-----------+--------------------+--------+---------------+
# |      11599|2013-07-25 00:00:...|       1|         CLOSED|
# |        256|2013-07-25 00:00:...|       2|PENDING_PAYMENT|
# |      12111|2013-07-25 00:00:...|       3|       COMPLETE|
# |       8827|2013-07-25 00:00:...|       4|         CLOSED|
# |      11318|2013-07-25 00:00:...|       5|       COMPLETE|
# |       7130|2013-07-25 00:00:...|       6|       COMPLETE|
# |       4530|2013-07-25 00:00:...|       7|       COMPLETE|
# |       2911|2013-07-25 00:00:...|       8|     PROCESSING|
# |       5657|2013-07-25 00:00:...|       9|PENDING_PAYMENT|
# |       5648|2013-07-25 00:00:...|      10|PENDING_PAYMENT|
# |        918|2013-07-25 00:00:...|      11| PAYMENT_REVIEW|
# |       1837|2013-07-25 00:00:...|      12|         CLOSED|
# |       9149|2013-07-25 00:00:...|      13|PENDING_PAYMENT|
# |       9842|2013-07-25 00:00:...|      14|     PROCESSING|
# |       2568|2013-07-25 00:00:...|      15|       COMPLETE|
# |       7276|2013-07-25 00:00:...|      16|PENDING_PAYMENT|
# |       2667|2013-07-25 00:00:...|      17|       COMPLETE|
# |       1205|2013-07-25 00:00:...|      18|         CLOSED|
# |       9488|2013-07-25 00:00:...|      19|PENDING_PAYMENT|
# |       9198|2013-07-25 00:00:...|      20|     PROCESSING|
# +-----------+--------------------+--------+---------------+
# only showing top 20 rows

# %%
df_json.printSchema()
# Out:
# root
#  |-- customer_id: long (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- order_id: long (nullable = true)
#  |-- order_status: string (nullable = true)

# %%
df_orc = spark.read.orc("/Volumes/workspace/spark_practice/datasets/part-00000-a7dd3808-5d4c-422c-b54c-2897feebb485-c000.snappy.orc")
df_orc.show()
# Out:
# +-----------+--------------------+--------+---------------+
# |customer_id|          order_date|order_id|   order_status|
# +-----------+--------------------+--------+---------------+
# |      11599|2013-07-25 00:00:...|       1|         CLOSED|
# |        256|2013-07-25 00:00:...|       2|PENDING_PAYMENT|
# |      12111|2013-07-25 00:00:...|       3|       COMPLETE|
# |       8827|2013-07-25 00:00:...|       4|         CLOSED|
# |      11318|2013-07-25 00:00:...|       5|       COMPLETE|
# |       7130|2013-07-25 00:00:...|       6|       COMPLETE|
# |       4530|2013-07-25 00:00:...|       7|       COMPLETE|
# |       2911|2013-07-25 00:00:...|       8|     PROCESSING|
# |       5657|2013-07-25 00:00:...|       9|PENDING_PAYMENT|
# |       5648|2013-07-25 00:00:...|      10|PENDING_PAYMENT|
# |        918|2013-07-25 00:00:...|      11| PAYMENT_REVIEW|
# |       1837|2013-07-25 00:00:...|      12|         CLOSED|
# |       9149|2013-07-25 00:00:...|      13|PENDING_PAYMENT|
# |       9842|2013-07-25 00:00:...|      14|     PROCESSING|
# |       2568|2013-07-25 00:00:...|      15|       COMPLETE|
# |       7276|2013-07-25 00:00:...|      16|PENDING_PAYMENT|
# |       2667|2013-07-25 00:00:...|      17|       COMPLETE|
# |       1205|2013-07-25 00:00:...|      18|         CLOSED|
# |       9488|2013-07-25 00:00:...|      19|PENDING_PAYMENT|
# |       9198|2013-07-25 00:00:...|      20|     PROCESSING|
# +-----------+--------------------+--------+---------------+
# only showing top 20 rows

# %%
df_orc.printSchema()
# Out:
# root
#  |-- customer_id: long (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- order_id: long (nullable = true)
#  |-- order_status: string (nullable = true)

# %% [markdown]
# Update column name order_status to status in **df_json** df

# %%
df_json2 = df_json.withColumnRenamed("order_status","status")
df_json2.show()
# Out:
# +-----------+--------------------+--------+---------------+
# |customer_id|          order_date|order_id|         status|
# +-----------+--------------------+--------+---------------+
# |      11599|2013-07-25 00:00:...|       1|         CLOSED|
# |        256|2013-07-25 00:00:...|       2|PENDING_PAYMENT|
# |      12111|2013-07-25 00:00:...|       3|       COMPLETE|
# |       8827|2013-07-25 00:00:...|       4|         CLOSED|
# |      11318|2013-07-25 00:00:...|       5|       COMPLETE|
# |       7130|2013-07-25 00:00:...|       6|       COMPLETE|
# |       4530|2013-07-25 00:00:...|       7|       COMPLETE|
# |       2911|2013-07-25 00:00:...|       8|     PROCESSING|
# |       5657|2013-07-25 00:00:...|       9|PENDING_PAYMENT|
# |       5648|2013-07-25 00:00:...|      10|PENDING_PAYMENT|
# |        918|2013-07-25 00:00:...|      11| PAYMENT_REVIEW|
# |       1837|2013-07-25 00:00:...|      12|         CLOSED|
# |       9149|2013-07-25 00:00:...|      13|PENDING_PAYMENT|
# |       9842|2013-07-25 00:00:...|      14|     PROCESSING|
# |       2568|2013-07-25 00:00:...|      15|       COMPLETE|
# |       7276|2013-07-25 00:00:...|      16|PENDING_PAYMENT|
# |       2667|2013-07-25 00:00:...|      17|       COMPLETE|
# |       1205|2013-07-25 00:00:...|      18|         CLOSED|
# |       9488|2013-07-25 00:00:...|      19|PENDING_PAYMENT|
# |       9198|2013-07-25 00:00:...|      20|     PROCESSING|
# +-----------+--------------------+--------+---------------+
# only showing top 20 rows

# %% [markdown]
# change datatype from string to timestamp in df_json df

# %%
from pyspark.sql.functions import *
df_json3 = df_json2.withColumn("order_date_new",to_timestamp(df_json2.order_date))
df_json4 = df_json3.drop("order_date")
df_json4.show()
# Out:
# +-----------+--------+---------------+-------------------+
# |customer_id|order_id|         status|     order_date_new|
# +-----------+--------+---------------+-------------------+
# |      11599|       1|         CLOSED|2013-07-25 00:00:00|
# |        256|       2|PENDING_PAYMENT|2013-07-25 00:00:00|
# |      12111|       3|       COMPLETE|2013-07-25 00:00:00|
# |       8827|       4|         CLOSED|2013-07-25 00:00:00|
# |      11318|       5|       COMPLETE|2013-07-25 00:00:00|
# |       7130|       6|       COMPLETE|2013-07-25 00:00:00|
# |       4530|       7|       COMPLETE|2013-07-25 00:00:00|
# |       2911|       8|     PROCESSING|2013-07-25 00:00:00|
# |       5657|       9|PENDING_PAYMENT|2013-07-25 00:00:00|
# |       5648|      10|PENDING_PAYMENT|2013-07-25 00:00:00|
# |        918|      11| PAYMENT_REVIEW|2013-07-25 00:00:00|
# |       1837|      12|         CLOSED|2013-07-25 00:00:00|
# |       9149|      13|PENDING_PAYMENT|2013-07-25 00:00:00|
# |       9842|      14|     PROCESSING|2013-07-25 00:00:00|
# |       2568|      15|       COMPLETE|2013-07-25 00:00:00|
# |       7276|      16|PENDING_PAYMENT|2013-07-25 00:00:00|
# |       2667|      17|       COMPLETE|2013-07-25 00:00:00|
# |       1205|      18|         CLOSED|2013-07-25 00:00:00|
# |       9488|      19|PENDING_PAYMENT|2013-07-25 00:00:00|
# |       9198|      20|     PROCESSING|2013-07-25 00:00:00|
# +-----------+--------+---------------+-------------------+
# only showing top 20 rows

# %%
df_json4.printSchema()
# Out:
# root
#  |-- customer_id: long (nullable = true)
#  |-- order_id: long (nullable = true)
#  |-- status: string (nullable = true)
#  |-- order_date_new: timestamp (nullable = true)

# %%
df_json5 = df_json4.filter("status= 'CLOSED'")
# df_json5 = df_json4.where("status= 'CLOSED'")
df_json5.show()
df_json5.count()
# Out:
# +-----------+--------+------+-------------------+
# |customer_id|order_id|status|     order_date_new|
# +-----------+--------+------+-------------------+
# |      11599|       1|CLOSED|2013-07-25 00:00:00|
# |       8827|       4|CLOSED|2013-07-25 00:00:00|
# |       1837|      12|CLOSED|2013-07-25 00:00:00|
# |       1205|      18|CLOSED|2013-07-25 00:00:00|
# |      11441|      24|CLOSED|2013-07-25 00:00:00|
# |       9503|      25|CLOSED|2013-07-25 00:00:00|
# |       5863|      37|CLOSED|2013-07-25 00:00:00|
# |      12271|      51|CLOSED|2013-07-25 00:00:00|
# |       7073|      57|CLOSED|2013-07-25 00:00:00|
# |       4791|      61|CLOSED|2013-07-25 00:00:00|
# |       9111|      62|CLOSED|2013-07-25 00:00:00|
# |       3065|      87|CLOSED|2013-07-25 00:00:00|
# |       9131|      90|CLOSED|2013-07-25 00:00:00|
# |       5116|     101|CLOSED|2013-07-25 00:00:00|
# |       8763|     116|CLOSED|2013-07-26 00:00:00|
# |       9937|     129|CLOSED|2013-07-26 00:00:00|
# |      10604|     133|CLOSED|2013-07-26 00:00:00|
# |         16|     191|CLOSED|2013-07-26 00:00:00|
# |       9055|     201|CLOSED|2013-07-26 00:00:00|
# |      10372|     211|CLOSED|2013-07-26 00:00:00|
# +-----------+--------+------+-------------------+
# only showing top 20 rows
# 7556

# %% [markdown]
# read a table

# %%
df_table  = spark.read.table("workspace.spark_practice.orders_table")
df_table.show(5)
df_table.count()
# Out:
# +--------+----------+-------+---------------+
# |order_id|order_date|cust_id|   order_status|
# +--------+----------+-------+---------------+
# |       1|2013-07-25|  11599|         CLOSED|
# |       2|2013-07-25|    256|PENDING_PAYMENT|
# |       3|2013-07-25|  12111|       COMPLETE|
# |       4|2013-07-25|   8827|         CLOSED|
# |       5|2013-07-25|  11318|       COMPLETE|
# +--------+----------+-------+---------------+
# only showing top 5 rows
# 3081900

# %% [markdown]
# create table from df

# %%
df_json5.createOrReplaceTempView("orders_table")

# %%
df = spark.sql("select * from orders_table where status = 'CLOSED'")
df.show()
df.count()
# Out:
# +-----------+--------+------+-------------------+
# |customer_id|order_id|status|     order_date_new|
# +-----------+--------+------+-------------------+
# |      11599|       1|CLOSED|2013-07-25 00:00:00|
# |       8827|       4|CLOSED|2013-07-25 00:00:00|
# |       1837|      12|CLOSED|2013-07-25 00:00:00|
# |       1205|      18|CLOSED|2013-07-25 00:00:00|
# |      11441|      24|CLOSED|2013-07-25 00:00:00|
# |       9503|      25|CLOSED|2013-07-25 00:00:00|
# |       5863|      37|CLOSED|2013-07-25 00:00:00|
# |      12271|      51|CLOSED|2013-07-25 00:00:00|
# |       7073|      57|CLOSED|2013-07-25 00:00:00|
# |       4791|      61|CLOSED|2013-07-25 00:00:00|
# |       9111|      62|CLOSED|2013-07-25 00:00:00|
# |       3065|      87|CLOSED|2013-07-25 00:00:00|
# |       9131|      90|CLOSED|2013-07-25 00:00:00|
# |       5116|     101|CLOSED|2013-07-25 00:00:00|
# |       8763|     116|CLOSED|2013-07-26 00:00:00|
# |       9937|     129|CLOSED|2013-07-26 00:00:00|
# |      10604|     133|CLOSED|2013-07-26 00:00:00|
# |         16|     191|CLOSED|2013-07-26 00:00:00|
# |       9055|     201|CLOSED|2013-07-26 00:00:00|
# |      10372|     211|CLOSED|2013-07-26 00:00:00|
# +-----------+--------+------+-------------------+
# only showing top 20 rows
# 7556

# %%
df_from_table = table('orders_table')
df_from_table.show()
df_from_table.count()
# Out:
# +-----------+--------+------+-------------------+
# |customer_id|order_id|status|     order_date_new|
# +-----------+--------+------+-------------------+
# |      11599|       1|CLOSED|2013-07-25 00:00:00|
# |       8827|       4|CLOSED|2013-07-25 00:00:00|
# |       1837|      12|CLOSED|2013-07-25 00:00:00|
# |       1205|      18|CLOSED|2013-07-25 00:00:00|
# |      11441|      24|CLOSED|2013-07-25 00:00:00|
# |       9503|      25|CLOSED|2013-07-25 00:00:00|
# |       5863|      37|CLOSED|2013-07-25 00:00:00|
# |      12271|      51|CLOSED|2013-07-25 00:00:00|
# |       7073|      57|CLOSED|2013-07-25 00:00:00|
# |       4791|      61|CLOSED|2013-07-25 00:00:00|
# |       9111|      62|CLOSED|2013-07-25 00:00:00|
# |       3065|      87|CLOSED|2013-07-25 00:00:00|
# |       9131|      90|CLOSED|2013-07-25 00:00:00|
# |       5116|     101|CLOSED|2013-07-25 00:00:00|
# |       8763|     116|CLOSED|2013-07-26 00:00:00|
# |       9937|     129|CLOSED|2013-07-26 00:00:00|
# |      10604|     133|CLOSED|2013-07-26 00:00:00|
# |         16|     191|CLOSED|2013-07-26 00:00:00|
# |       9055|     201|CLOSED|2013-07-26 00:00:00|
# |      10372|     211|CLOSED|2013-07-26 00:00:00|
# +-----------+--------+------+-------------------+
# only showing top 20 rows
# 7556

# %%
# %sql
select * from orders_table where customer_id = 10604;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>order_id</th><th>status</th><th>order_date_new</th></tr></thead><tbody><tr><td>10604</td><td>133</td><td>CLOSED</td><td>2013-07-26T00:00:00.000Z</td></tr><tr><td>10604</td><td>9431</td><td>CLOSED</td><td>2013-09-22T00:00:00.000Z</td></tr></tbody></table></div>
