# %%
from pyspark.sql import SparkSession
import getpass

username = getpass.getuser()

spark = SparkSession.builder \
    .appName("itv023333") \
    .master("yarn") \
    .config("spark.ui.port", "0") \
    .config("spark.sql.warehouse.dir", f"/user/{username}/warehouse") \
    .enableHiveSupport() \
    .getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://g01.itversity.com:38849">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>itv023333</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
orders_schema = "customer_id long, order_date date, order_id long, order_status string"

# %%
orders_df = spark.read \
.format("csv") \
.schema(orders_schema) \
.load("/public/trendytech/orders/orders_1gb.csv")

# %%
orders_df.show()
# Out:
# +-----------+----------+--------+---------------+
# |customer_id|order_date|order_id|   order_status|
# +-----------+----------+--------+---------------+
# |          1|2013-07-25|   11599|         CLOSED|
# |          2|2013-07-25|     256|PENDING_PAYMENT|
# |          3|2013-07-25|   12111|       COMPLETE|
# |          4|2013-07-25|    8827|         CLOSED|
# |          5|2013-07-25|   11318|       COMPLETE|
# |          6|2013-07-25|    7130|       COMPLETE|
# |          7|2013-07-25|    4530|       COMPLETE|
# |          8|2013-07-25|    2911|     PROCESSING|
# |          9|2013-07-25|    5657|PENDING_PAYMENT|
# |         10|2013-07-25|    5648|PENDING_PAYMENT|
# |         11|2013-07-25|     918| PAYMENT_REVIEW|
# |         12|2013-07-25|    1837|         CLOSED|
# |         13|2013-07-25|    9149|PENDING_PAYMENT|
# |         14|2013-07-25|    9842|     PROCESSING|
# |         15|2013-07-25|    2568|       COMPLETE|
# |         16|2013-07-25|    7276|PENDING_PAYMENT|
# |         17|2013-07-25|    2667|       COMPLETE|
# |         18|2013-07-25|    1205|         CLOSED|
# |         19|2013-07-25|    9488|PENDING_PAYMENT|
# |         20|2013-07-25|    9198|     PROCESSING|
# +-----------+----------+--------+---------------+
# only showing top 20 rows

# %%
orders_df.rdd.getNumPartitions()
# Out:
# 9

# %% [markdown]
# lets apply a groupBy()

# %%
orders_df.groupBy("order_status").count().write.format("csv").mode("overwrite").save("groupBy")

# %% [markdown]
# lets perform joins and broadcast joins

# %%
left_data = [
    ("101",1,"closed"),
    ("102",2,"complete"),
    ("103",3,"pending"),
    ("104",4,"closed")
]

# %%
left_df= spark.createDataFrame(left_data,["order_id", "cust_id","status string"])

# %%
left_df.show()
# Out:
# +--------+-------+-------------+
# |order_id|cust_id|status string|
# +--------+-------+-------------+
# |     101|      1|       closed|
# |     102|      2|     complete|
# |     103|      3|      pending|
# |     104|      4|       closed|
# +--------+-------+-------------+

# %%
left_df.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- cust_id: long (nullable = true)
#  |-- status string: string (nullable = true)

# %%
right_data = [
    (1,"banglore"),
    (2,"pune"),
    (5,"mumbai")
]

# %%
right_df = spark.createDataFrame(right_data, ["cust_id","city"])

# %%
right_df.show()
# Out:
# +-------+--------+
# |cust_id|    city|
# +-------+--------+
# |      1|banglore|
# |      2|    pune|
# |      5|  mumbai|
# +-------+--------+

# %%
right_df.printSchema()
# Out:
# root
#  |-- cust_id: long (nullable = true)
#  |-- city: string (nullable = true)

# %%
left_df.join(right_df,left_df.cust_id == right_df.cust_id,"inner").show()
# Out:
# +--------+-------+-------------+-------+--------+
# |order_id|cust_id|status string|cust_id|    city|
# +--------+-------+-------------+-------+--------+
# |     101|      1|       closed|      1|banglore|
# |     102|      2|     complete|      2|    pune|
# +--------+-------+-------------+-------+--------+

# %%
left_df.join(right_df,left_df.cust_id == right_df.cust_id,"left").show()
# Out:
# +--------+-------+-------------+-------+--------+
# |order_id|cust_id|status string|cust_id|    city|
# +--------+-------+-------------+-------+--------+
# |     101|      1|       closed|      1|banglore|
# |     103|      3|      pending|   null|    null|
# |     102|      2|     complete|      2|    pune|
# |     104|      4|       closed|   null|    null|
# +--------+-------+-------------+-------+--------+

# %%
left_df.join(right_df,left_df.cust_id == right_df.cust_id,"right").show()
# Out:
# +--------+-------+-------------+-------+--------+
# |order_id|cust_id|status string|cust_id|    city|
# +--------+-------+-------------+-------+--------+
# |    null|   null|         null|      5|  mumbai|
# |     101|      1|       closed|      1|banglore|
# |     102|      2|     complete|      2|    pune|
# +--------+-------+-------------+-------+--------+

# %%
left_df.join(right_df,left_df.cust_id == right_df.cust_id,"full").show()
# Out:
# +--------+-------+-------------+-------+--------+
# |order_id|cust_id|status string|cust_id|    city|
# +--------+-------+-------------+-------+--------+
# |    null|   null|         null|      5|  mumbai|
# |     101|      1|       closed|      1|banglore|
# |     103|      3|      pending|   null|    null|
# |     102|      2|     complete|      2|    pune|
# |     104|      4|       closed|   null|    null|
# +--------+-------+-------------+-------+--------+

# %%
cust_schema = "customer_id long, fname string, lname string, username string, password string, address string, city string, state string, pincode long"

# %%
cust_df = spark.read \
.format("csv") \
.schema(cust_schema) \
.load("/public/trendytech/retail_db/customers")

# %%
cust_df.show()
# Out:
# +-----------+-----------+---------+---------+---------+--------------------+-------------+-----+-------+
# |customer_id|      fname|    lname| username| password|             address|         city|state|pincode|
# +-----------+-----------+---------+---------+---------+--------------------+-------------+-----+-------+
# |          1|    Richard|Hernandez|XXXXXXXXX|XXXXXXXXX|  6303 Heather Plaza|  Brownsville|   TX|  78521|
# |          2|       Mary|  Barrett|XXXXXXXXX|XXXXXXXXX|9526 Noble Embers...|    Littleton|   CO|  80126|
# |          3|        Ann|    Smith|XXXXXXXXX|XXXXXXXXX|3422 Blue Pioneer...|       Caguas|   PR|    725|
# |          4|       Mary|    Jones|XXXXXXXXX|XXXXXXXXX|  8324 Little Common|   San Marcos|   CA|  92069|
# |          5|     Robert|   Hudson|XXXXXXXXX|XXXXXXXXX|10 Crystal River ...|       Caguas|   PR|    725|
# |          6|       Mary|    Smith|XXXXXXXXX|XXXXXXXXX|3151 Sleepy Quail...|      Passaic|   NJ|   7055|
# |          7|    Melissa|   Wilcox|XXXXXXXXX|XXXXXXXXX|9453 High Concession|       Caguas|   PR|    725|
# |          8|      Megan|    Smith|XXXXXXXXX|XXXXXXXXX|3047 Foggy Forest...|     Lawrence|   MA|   1841|
# |          9|       Mary|    Perez|XXXXXXXXX|XXXXXXXXX| 3616 Quaking Street|       Caguas|   PR|    725|
# |         10|    Melissa|    Smith|XXXXXXXXX|XXXXXXXXX|8598 Harvest Beac...|     Stafford|   VA|  22554|
# |         11|       Mary|  Huffman|XXXXXXXXX|XXXXXXXXX|    3169 Stony Woods|       Caguas|   PR|    725|
# |         12|Christopher|    Smith|XXXXXXXXX|XXXXXXXXX|5594 Jagged Ember...|  San Antonio|   TX|  78227|
# |         13|       Mary|  Baldwin|XXXXXXXXX|XXXXXXXXX|7922 Iron Oak Gar...|       Caguas|   PR|    725|
# |         14|  Katherine|    Smith|XXXXXXXXX|XXXXXXXXX|5666 Hazy Pony Sq...|  Pico Rivera|   CA|  90660|
# |         15|       Jane|     Luna|XXXXXXXXX|XXXXXXXXX|    673 Burning Glen|      Fontana|   CA|  92336|
# |         16|    Tiffany|    Smith|XXXXXXXXX|XXXXXXXXX|      6651 Iron Port|       Caguas|   PR|    725|
# |         17|       Mary| Robinson|XXXXXXXXX|XXXXXXXXX|     1325 Noble Pike|       Taylor|   MI|  48180|
# |         18|     Robert|    Smith|XXXXXXXXX|XXXXXXXXX|2734 Hazy Butterf...|     Martinez|   CA|  94553|
# |         19|  Stephanie| Mitchell|XXXXXXXXX|XXXXXXXXX|3543 Red Treasure...|       Caguas|   PR|    725|
# |         20|       Mary|    Ellis|XXXXXXXXX|XXXXXXXXX|      4703 Old Route|West New York|   NJ|   7093|
# +-----------+-----------+---------+---------+---------+--------------------+-------------+-----+-------+
# only showing top 20 rows

# %%
orders_df.join(cust_df, orders_df.customer_id == cust_df.customer_id, "inner").show()
# Out:
# +-----------+----------+--------+---------------+-----------+-----------+---------+---------+---------+--------------------+-------------+-----+-------+
# |customer_id|order_date|order_id|   order_status|customer_id|      fname|    lname| username| password|             address|         city|state|pincode|
# +-----------+----------+--------+---------------+-----------+-----------+---------+---------+---------+--------------------+-------------+-----+-------+
# |          1|2013-07-25|   11599|         CLOSED|          1|    Richard|Hernandez|XXXXXXXXX|XXXXXXXXX|  6303 Heather Plaza|  Brownsville|   TX|  78521|
# |          2|2013-07-25|     256|PENDING_PAYMENT|          2|       Mary|  Barrett|XXXXXXXXX|XXXXXXXXX|9526 Noble Embers...|    Littleton|   CO|  80126|
# |          3|2013-07-25|   12111|       COMPLETE|          3|        Ann|    Smith|XXXXXXXXX|XXXXXXXXX|3422 Blue Pioneer...|       Caguas|   PR|    725|
# |          4|2013-07-25|    8827|         CLOSED|          4|       Mary|    Jones|XXXXXXXXX|XXXXXXXXX|  8324 Little Common|   San Marcos|   CA|  92069|
# |          5|2013-07-25|   11318|       COMPLETE|          5|     Robert|   Hudson|XXXXXXXXX|XXXXXXXXX|10 Crystal River ...|       Caguas|   PR|    725|
# |          6|2013-07-25|    7130|       COMPLETE|          6|       Mary|    Smith|XXXXXXXXX|XXXXXXXXX|3151 Sleepy Quail...|      Passaic|   NJ|   7055|
# |          7|2013-07-25|    4530|       COMPLETE|          7|    Melissa|   Wilcox|XXXXXXXXX|XXXXXXXXX|9453 High Concession|       Caguas|   PR|    725|
# |          8|2013-07-25|    2911|     PROCESSING|          8|      Megan|    Smith|XXXXXXXXX|XXXXXXXXX|3047 Foggy Forest...|     Lawrence|   MA|   1841|
# |          9|2013-07-25|    5657|PENDING_PAYMENT|          9|       Mary|    Perez|XXXXXXXXX|XXXXXXXXX| 3616 Quaking Street|       Caguas|   PR|    725|
# |         10|2013-07-25|    5648|PENDING_PAYMENT|         10|    Melissa|    Smith|XXXXXXXXX|XXXXXXXXX|8598 Harvest Beac...|     Stafford|   VA|  22554|
# |         11|2013-07-25|     918| PAYMENT_REVIEW|         11|       Mary|  Huffman|XXXXXXXXX|XXXXXXXXX|    3169 Stony Woods|       Caguas|   PR|    725|
# |         12|2013-07-25|    1837|         CLOSED|         12|Christopher|    Smith|XXXXXXXXX|XXXXXXXXX|5594 Jagged Ember...|  San Antonio|   TX|  78227|
# |         13|2013-07-25|    9149|PENDING_PAYMENT|         13|       Mary|  Baldwin|XXXXXXXXX|XXXXXXXXX|7922 Iron Oak Gar...|       Caguas|   PR|    725|
# |         14|2013-07-25|    9842|     PROCESSING|         14|  Katherine|    Smith|XXXXXXXXX|XXXXXXXXX|5666 Hazy Pony Sq...|  Pico Rivera|   CA|  90660|
# |         15|2013-07-25|    2568|       COMPLETE|         15|       Jane|     Luna|XXXXXXXXX|XXXXXXXXX|    673 Burning Glen|      Fontana|   CA|  92336|
# |         16|2013-07-25|    7276|PENDING_PAYMENT|         16|    Tiffany|    Smith|XXXXXXXXX|XXXXXXXXX|      6651 Iron Port|       Caguas|   PR|    725|
# |         17|2013-07-25|    2667|       COMPLETE|         17|       Mary| Robinson|XXXXXXXXX|XXXXXXXXX|     1325 Noble Pike|       Taylor|   MI|  48180|
# |         18|2013-07-25|    1205|         CLOSED|         18|     Robert|    Smith|XXXXXXXXX|XXXXXXXXX|2734 Hazy Butterf...|     Martinez|   CA|  94553|
# |         19|2013-07-25|    9488|PENDING_PAYMENT|         19|  Stephanie| Mitchell|XXXXXXXXX|XXXXXXXXX|3543 Red Treasure...|       Caguas|   PR|    725|
# |         20|2013-07-25|    9198|     PROCESSING|         20|       Mary|    Ellis|XXXXXXXXX|XXXXXXXXX|      4703 Old Route|West New York|   NJ|   7093|
# +-----------+----------+--------+---------------+-----------+-----------+---------+---------+---------+--------------------+-------------+-----+-------+
# only showing top 20 rows

# %%
spark.conf.set("spark.sql.autoBroadcastJoinThreshold", 10 * 1024 * 1024)

# %%
spark.conf.set("spark.sql.autoBroadcastJoinThreshold", "-1")

# %%
spark.conf.get("spark.sql.autoBroadcastJoinThreshold")
# Out:
# '-1'

# %%
orders_df.join(cust_df, orders_df.customer_id == cust_df.customer_id, "inner").write.format("noop").mode("overwrite").save()
